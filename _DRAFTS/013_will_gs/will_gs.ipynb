# %% [markdown]
# # Schopenhauer's Will as Unsayable Events in General Semantics

# %% [markdown]
# The Will as ceaseless striving to existence.
#
# The Event layer, with things that are no-things. They have no color, smell, shape, or properties as we typically think of them. Must resist the urge to cast any kind of knowability into this realm.
# These are
